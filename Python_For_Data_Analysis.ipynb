# %%
import pandas as pd
import os
import sqldf

# %%
customer = pd.read_excel('C:\\Users\\ASUS\\OneDrive\\Python_Data_Analytics\\Gen2\\Class 3\\DA_TEST_1\\customers (UK).xlsx')

# %%
customer.head(5)
# Out:
#    ID              FirstName               LastName              Country  \
# 0   0     V0.296680287495188     L0.104646531512644          FR - France
# 1   1     D0.793097101838541   Law0.141693355411763        GER - Germany
# 2   2   Ker0.141418247925814    Ng0.753960335680345          FR - France
# 3   3   Fik0.950054552966336     F0.590961171612745  UK - United Kingdom
# 4   4  Iona0.294287981536498  Ison0.826191754811968           IT - Italy
#
#   DateJoined Gender   Birthday Newsletter
# 0 2015-12-18    NaN 1968-02-03          N
# 1 2015-12-21      M 2009-10-06          Y
# 2 2015-12-22      F 1990-08-04          Y
# 3 2015-12-22      M 1974-07-24          N
# 4 2015-12-22      M 1981-08-13          N

# %%
customer_transaction = pd.read_excel('C:\\Users\\ASUS\\OneDrive\\Python_Data_Analytics\\Gen2\\Class 3\\DA_TEST_1\\customers (UK).xlsx',sheet_name = 'Customer transactions')

# %%
customer_transaction.head(5)
# Out:
#    OrderID  CustomerID  ItemID TransactionDate   Channel
# 0        0           0     352      2020-03-21  In Store
# 1        0           0    3433      2020-07-14  In Store
# 2        0           0   11162      2020-08-09  In Store
# 3        0           0   13011      2020-12-07  In Store
# 4        0           0   13885      2020-11-08  In Store

# %%
items = pd.read_excel('C:\\Users\\ASUS\\OneDrive\\Python_Data_Analytics\\Gen2\\Class 3\\DA_TEST_1\\customers (UK).xlsx',sheet_name = 'Items')

# %%
items.head(5)
# Out:
#    ItemID                     Product             Brand  SellPrice  CostPrice
# 0       1  032irview0.686128260621012  Ki)D3jDmA,RIP68X        943        359
# 1       2  070ttream0.518887735674677  GO4582ey<S!+k1VE        717        207
# 2       3  070htream0.333307794468401  G.Kb^jz*soY!(-4Q        739        199
# 3       4  100Grseys0.271522111052549  Dr|vm[-5p~56Y\mk        532        262
# 4       5  100[nside0.645837365801341  Dr|vm[-5p~56Y\mk        593        392

# %%
items.tail(5)
# Out:
#        ItemID                      Product             Brand  SellPrice  \
# 17884   17885   zarzmodel0.705343660670698  Zah<@kD,N[Vo]vf        202
# 17885   17886   zelQailer0.599088919243258  Nia_TfHUVDtT>6-s        463
# 17886   17887   zenyation0.980382120595891  Chbm3nL;wgcU<S(y        688
# 17887   17888   zenvition0.646980947183814  Ac8IJsKH,4xtY.Tk        157
# 17888   17889  zipBlease0.0313238391182887  Zi;R(P$t]{$);Ze!        707
#
#        CostPrice
# 17884         42
# 17885        131
# 17886        200
# 17887         63
# 17888        204

# %%
traffic_path = """C:\\Users\\ASUS\\OneDrive\\Python_Data_Analytics\\Gen2\\Class 3\\DA_TEST_1\\Traffic\\"""

# %%
transaction_01 = pd.read_excel(traffic_path+'2020_01.xlsx')

# %%
transaction_01
# Out:
#                                 Page URL   users  uniquePageviews  pageviews  \
# 0     /2020/1/032irview0.686128260621012  5669.2           5777.8     6286.4
# 1     /2020/1/070ttream0.518887735674677   359.8            370.4      403.4
# 2     /2020/1/070htream0.333307794468401   587.6            614.2      657.6
# 3     /2020/1/100Grseys0.271522111052549  1284.0           1308.6     1385.4
# 4     /2020/1/100[nside0.645837365801341  1846.0           1880.8     2025.0
# ...                                  ...     ...              ...        ...
# 1649  /2020/1/zahq-info0.658935603966331  1369.4           1398.8     1522.6
# 1650  /2020/1/zahIsplay0.382785581737682   430.4            435.4      473.2
# 1651  /2020/1/zebmtream0.721140974007164    38.8             39.4       44.2
# 1652  /2020/1/ziopys-pe0.315590636174329  1768.4           1790.6     1880.0
# 1653  /2020/1/zioo-jazz0.731425393269566  4733.0           4942.4     5169.6
#
# ...

# %%
list_files = os.listdir(traffic_path)

# %%
list_files
# Out:
# ['2020_01.xlsx',
#  '2020_02.xlsx',
#  '2020_03.xlsx',
#  '2020_04.xlsx',
#  '2020_05.xlsx',
#  '2020_06.xlsx',
#  '2020_07.xlsx',
#  '2020_08.xlsx',
#  '2020_09.xlsx',
#  '2020_10.xlsx',
#  '2020_11.xlsx',
#  '2020_12.xlsx']

# %%
list_files[1:]
# Out:
# ['2020_02.xlsx',
#  '2020_03.xlsx',
#  '2020_04.xlsx',
#  '2020_05.xlsx',
#  '2020_06.xlsx',
#  '2020_07.xlsx',
#  '2020_08.xlsx',
#  '2020_09.xlsx',
#  '2020_10.xlsx',
#  '2020_11.xlsx',
#  '2020_12.xlsx']

# %%
transaction_01 = pd.read_excel(traffic_path+'2020_01.xlsx')
for i in list_files[1:] :
    transaction_02 = pd.read_excel(traffic_path+i)
    transaction_01 = pd.concat([transaction_01,transaction_02])
    print('Processed file {}'.format(i))
# Out:
# Processed file 2020_02.xlsx
# Processed file 2020_03.xlsx
# Processed file 2020_04.xlsx
# Processed file 2020_05.xlsx
# Processed file 2020_06.xlsx
# Processed file 2020_07.xlsx
# Processed file 2020_08.xlsx
# Processed file 2020_09.xlsx
# Processed file 2020_10.xlsx
# Processed file 2020_11.xlsx
# Processed file 2020_12.xlsx

# %%
transaction_01
# Out:
#                                  Page URL   users  uniquePageviews  pageviews  \
# 0      /2020/1/032irview0.686128260621012  5669.2           5777.8     6286.4
# 1      /2020/1/070ttream0.518887735674677   359.8            370.4      403.4
# 2      /2020/1/070htream0.333307794468401   587.6            614.2      657.6
# 3      /2020/1/100Grseys0.271522111052549  1284.0           1308.6     1385.4
# 4      /2020/1/100[nside0.645837365801341  1846.0           1880.8     2025.0
# ..                                    ...     ...              ...        ...
# 461     /2020/12/yinfbowls0.6558670149224   130.0            133.2      142.2
# 462  /2020/12/yosolease0.0455049365834417   314.6            325.6      365.2
# 463   /2020/12/you^-info0.127669879156147  1419.6           1448.4     1615.8
# 464   /2020/12/youe-info0.729842478879044   483.8            487.6      509.6
# 465   /2020/12/zahJuseum0.120647638596675   823.2            837.6      886.8
#
# ...

# %%
total_pageview = transaction_01[['uniquePageviews','Posted On (DD/MM/YYYY)']]

# %%
transaction_01[['uniquePageviews','Posted On (DD/MM/YYYY)']]
# Out:
#      uniquePageviews Posted On (DD/MM/YYYY)
# 0             5777.8    2020-01-10 16:56:13
# 1              370.4    2020-01-10 05:04:35
# 2              614.2    2020-01-16 23:27:08
# 3             1308.6    2020-01-17 12:32:24
# 4             1880.8    2020-01-23 05:21:08
# ..               ...                    ...
# 461            133.2    2020-12-01 04:55:35
# 462            325.6    2020-12-03 15:25:00
# 463           1448.4    2020-12-06 23:57:54
# 464            487.6    2020-12-04 05:59:22
# 465            837.6    2020-12-05 23:49:29
#
# [17889 rows x 2 columns]

# %%
total_pageview.rename(columns={'Posted On (DD/MM/YYYY)':'Date'},inplace=True)
# Out:
# c:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
total_pageview.head(5)
# Out:
#    uniquePageviews                Date
# 0           5777.8 2020-01-10 16:56:13
# 1            370.4 2020-01-10 05:04:35
# 2            614.2 2020-01-16 23:27:08
# 3           1308.6 2020-01-17 12:32:24
# 4           1880.8 2020-01-23 05:21:08

# %%
total_pageview['Date2'] = total_pageview['Date'].dt.date
# Out:
# <ipython-input-31-600b780a0993>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_pageview['Date2'] = total_pageview['Date'].dt.date

# %%
total_pageview
# Out:
#      uniquePageviews                Date       Date2
# 0             5777.8 2020-01-10 16:56:13  2020-01-10
# 1              370.4 2020-01-10 05:04:35  2020-01-10
# 2              614.2 2020-01-16 23:27:08  2020-01-16
# 3             1308.6 2020-01-17 12:32:24  2020-01-17
# 4             1880.8 2020-01-23 05:21:08  2020-01-23
# ..               ...                 ...         ...
# 461            133.2 2020-12-01 04:55:35  2020-12-01
# 462            325.6 2020-12-03 15:25:00  2020-12-03
# 463           1448.4 2020-12-06 23:57:54  2020-12-06
# 464            487.6 2020-12-04 05:59:22  2020-12-04
# 465            837.6 2020-12-05 23:49:29  2020-12-05
#
# [17889 rows x 3 columns]

# %%
total_traffic = total_pageview.groupby('Date2').sum().reset_index()

# %%
total_traffic
# Out:
#           Date2  uniquePageviews
# 0    2020-01-01          64814.8
# 1    2020-01-02         113640.0
# 2    2020-01-03          65175.4
# 3    2020-01-04          14274.6
# 4    2020-01-05          47856.6
# ..          ...              ...
# 338  2020-12-05          24678.8
# 339  2020-12-06          26517.0
# 340  2020-12-07          97565.0
# 341  2020-12-08         105419.6
# 342  2020-12-09          50617.8
#
# [343 rows x 2 columns]

# %%
total_pageview = sqldf.run("""select sum(uniquePageviews) as Total_Pageview , date(Date) as Date from total_pageview group by date(Date)""")

# %%
total_pageview.head(5)
# Out:
#    Total_Pageview        Date
# 0         64814.8  2020-01-01
# 1        113640.0  2020-01-02
# 2         65175.4  2020-01-03
# 3         14274.6  2020-01-04
# 4         47856.6  2020-01-05

# %%
print(total_pageview.plot(x='Date',y='Total_Pageview',kind='line',figsize = [10,5]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
customer_transaction
# Out:
#        OrderID  CustomerID  ItemID TransactionDate   Channel
# 0            0           0     352      2020-03-21  In Store
# 1            0           0    3433      2020-07-14  In Store
# 2            0           0   11162      2020-08-09  In Store
# 3            0           0   13011      2020-12-07  In Store
# 4            0           0   13885      2020-11-08  In Store
# ...        ...         ...     ...             ...       ...
# 25208     8361         769   10053      2020-12-19  In Store
# 25209     8361         769   13162      2020-02-04  In Store
# 25210     8362         769    8727      2020-11-18  In Store
# 25211     8362         769   13065      2020-05-11  In Store
# 25212     8362         769   13577      2020-06-05  In Store
#
# [25213 rows x 5 columns]

# %%
items
# Out:
#        ItemID                      Product             Brand  SellPrice  \
# 0           1   032irview0.686128260621012  Ki)D3jDmA,RIP68X        943
# 1           2   070ttream0.518887735674677  GO4582ey<S!+k1VE        717
# 2           3   070htream0.333307794468401  G.Kb^jz*soY!(-4Q        739
# 3           4   100Grseys0.271522111052549  Dr|vm[-5p~56Y\mk        532
# 4           5   100[nside0.645837365801341  Dr|vm[-5p~56Y\mk        593
# ...       ...                          ...               ...        ...
# 17884   17885   zarzmodel0.705343660670698  Zah<@kD,N[Vo]vf        202
# 17885   17886   zelQailer0.599088919243258  Nia_TfHUVDtT>6-s        463
# 17886   17887   zenyation0.980382120595891  Chbm3nL;wgcU<S(y        688
# 17887   17888   zenvition0.646980947183814  Ac8IJsKH,4xtY.Tk        157
# 17888   17889  zipBlease0.0313238391182887  Zi;R(P$t]{$);Ze!        707
#
#        CostPrice
# 0            359
# 1            207
# 2            199
# 3            262
# ...

# %%
revenue = customer_transaction.merge(items, on = 'ItemID',how = 'left')

# %%
revenue_offline = revenue[revenue['Channel'] == 'In Store']

# %%
revenue_offline = revenue_offline[['TransactionDate','SellPrice']]

# %%
revenue_online = revenue[revenue['Channel'] == 'Online']

# %%
revenue_online = revenue_online[['TransactionDate','SellPrice']]

# %%
revenue_offline = revenue_offline.groupby('TransactionDate').sum().reset_index()

# %%
revenue_online = revenue_online.groupby('TransactionDate').sum().reset_index()

# %%
revenue_offline
# Out:
#     TransactionDate  SellPrice
# 0        2020-01-01      23820
# 1        2020-01-02      24069
# 2        2020-01-03      37118
# 3        2020-01-04      39946
# 4        2020-01-05      31844
# ..              ...        ...
# 319      2020-12-23      29118
# 320      2020-12-24      27640
# 321      2020-12-25      31697
# 322      2020-12-26      23072
# 323      2020-12-27      37629
#
# [324 rows x 2 columns]

# %%
revenue_online.rename(columns={'SellPrice':'Revenue'},inplace=True)

# %%
revenue_offline.rename(columns={'SellPrice':'Revenue'},inplace=True)

# %%
print(total_pageview.plot(x='Date',y='Total_Pageview',kind='line',figsize = [10,5]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(revenue_online.plot(x='TransactionDate',y='Revenue',kind='line',figsize = [10,5]))
# Out:
# AxesSubplot(0.125,0.2;0.775x0.68)

# %%
print(revenue_offline.plot(x='TransactionDate',y='Revenue',kind='line',figsize = [10,5]))
# Out:
# AxesSubplot(0.125,0.2;0.775x0.68)

# %% [markdown]
# <b> 2.	Sản phẩm nào mang lại pageviews và doanh thu  <b>

# %%
revenue
# Out:
#        OrderID  CustomerID  ItemID TransactionDate   Channel  \
# 0            0           0     352      2020-03-21  In Store
# 1            0           0    3433      2020-07-14  In Store
# 2            0           0   11162      2020-08-09  In Store
# 3            0           0   13011      2020-12-07  In Store
# 4            0           0   13885      2020-11-08  In Store
# ...        ...         ...     ...             ...       ...
# 25208     8361         769   10053      2020-12-19  In Store
# 25209     8361         769   13162      2020-02-04  In Store
# 25210     8362         769    8727      2020-11-18  In Store
# 25211     8362         769   13065      2020-05-11  In Store
# 25212     8362         769   13577      2020-06-05  In Store
#
#                            Product             Brand  SellPrice  CostPrice
# 0       chrUrumor0.784919078952733  MouDd/fn,XEARhBp        735        426
# 1       corGvideo0.268391324982493  muy(D#"d02`vwt_^        963        491
# ...

# %%
traffic = transaction_01

# %%
traffic
# Out:
#                                  Page URL   users  uniquePageviews  pageviews  \
# 0      /2020/1/032irview0.686128260621012  5669.2           5777.8     6286.4
# 1      /2020/1/070ttream0.518887735674677   359.8            370.4      403.4
# 2      /2020/1/070htream0.333307794468401   587.6            614.2      657.6
# 3      /2020/1/100Grseys0.271522111052549  1284.0           1308.6     1385.4
# 4      /2020/1/100[nside0.645837365801341  1846.0           1880.8     2025.0
# ..                                    ...     ...              ...        ...
# 461     /2020/12/yinfbowls0.6558670149224   130.0            133.2      142.2
# 462  /2020/12/yosolease0.0455049365834417   314.6            325.6      365.2
# 463   /2020/12/you^-info0.127669879156147  1419.6           1448.4     1615.8
# 464   /2020/12/youe-info0.729842478879044   483.8            487.6      509.6
# 465   /2020/12/zahJuseum0.120647638596675   823.2            837.6      886.8
#
# ...

# %%
revenue[revenue['Product'] == '032irview0.686128260621012']
# Out:
#        OrderID  CustomerID  ItemID TransactionDate   Channel  \
# 21674     7193         660       1      2020-03-09  In Store
#
#                           Product             Brand  SellPrice  CostPrice
# 21674  032irview0.686128260621012  Ki)D3jDmA,RIP68X        943        359

# %%
transaction_01[transaction_01['Page URL'] == '/2020/1/032irview0.686128260621012']
# Out:
#                              Page URL   users  uniquePageviews  pageviews  \
# 0  /2020/1/032irview0.686128260621012  5669.2           5777.8     6286.4
#
#               Brand Posted On (DD/MM/YYYY)
# 0  Ki)D3jDmA,RIP68X    2020-01-10 16:56:13

# %%
transaction_01[transaction_01['Page URL'] == '/2020/1/032irview0.686128260621012']['Page URL'].str.split('/')[0][-1]
# Out:
# '032irview0.686128260621012'

# %%
product_list = []

# %%
product_list
# Out:
# ['032irview0.686128260621012',
#  '070ttream0.518887735674677',
#  '070htream0.333307794468401',
#  '100Grseys0.271522111052549',
#  '100[nside0.645837365801341',
#  '101Hition0.428000735843647',
#  '101Tation0.58144832266657',
#  '101s-info0.671227295694652',
#  '101clease0.915823550778048',
#  '101Dlease0.745305177696334',
#  '101Q-week0.370225077449233',
#  '101W-info0.814078992987125',
#  '101G-info0.94681563230004',
#  '101C-info0.974274363285455',
#  '101]rce-10.242576440354746',
#  '101Kliams0.340353199113213',
#  '11-Pollab0.461435396979507',
#  '17-Id-day0.881755395091463',
#  '195ef-one0.581252589466607',
#  '195lction0.0671003825064809',
#  '197zginal0.0374548006914871',
#  '198import0.185194638074351',
#  '199Gailer0.647678041378019',
#  '199kassic0.148714723999901',
#  '2-cPvideo0.38275593287073',
#  '2-cMwatch0.426712546357366',
#  '2-ceement0.0351629936642824',
#  '201_-info0.0379437658715687',
#  '202hoenix0.747467506367503',
#  '202Stwigs0.920946364931357',
# ...

# %%
for i in transaction_01['Page URL'].str.split('/'):
    a = i[3]
    product_list.append(a)

# %%
transaction_01['Product'] = product_list

# %%
transaction_01
# Out:
#                                  Page URL   users  uniquePageviews  pageviews  \
# 0      /2020/1/032irview0.686128260621012  5669.2           5777.8     6286.4
# 1      /2020/1/070ttream0.518887735674677   359.8            370.4      403.4
# 2      /2020/1/070htream0.333307794468401   587.6            614.2      657.6
# 3      /2020/1/100Grseys0.271522111052549  1284.0           1308.6     1385.4
# 4      /2020/1/100[nside0.645837365801341  1846.0           1880.8     2025.0
# ..                                    ...     ...              ...        ...
# 461     /2020/12/yinfbowls0.6558670149224   130.0            133.2      142.2
# 462  /2020/12/yosolease0.0455049365834417   314.6            325.6      365.2
# 463   /2020/12/you^-info0.127669879156147  1419.6           1448.4     1615.8
# 464   /2020/12/youe-info0.729842478879044   483.8            487.6      509.6
# 465   /2020/12/zahJuseum0.120647638596675   823.2            837.6      886.8
#
# ...

# %% [markdown]
# <b> 2nd approach <b>

# %%
transaction_01['Product_lambda'] = transaction_01['Page URL'].apply(lambda x: x.split('/')[3])

# %%
transaction_01
# Out:
#                                  Page URL   users  uniquePageviews  pageviews  \
# 0      /2020/1/032irview0.686128260621012  5669.2           5777.8     6286.4
# 1      /2020/1/070ttream0.518887735674677   359.8            370.4      403.4
# 2      /2020/1/070htream0.333307794468401   587.6            614.2      657.6
# 3      /2020/1/100Grseys0.271522111052549  1284.0           1308.6     1385.4
# 4      /2020/1/100[nside0.645837365801341  1846.0           1880.8     2025.0
# ..                                    ...     ...              ...        ...
# 461     /2020/12/yinfbowls0.6558670149224   130.0            133.2      142.2
# 462  /2020/12/yosolease0.0455049365834417   314.6            325.6      365.2
# 463   /2020/12/you^-info0.127669879156147  1419.6           1448.4     1615.8
# 464   /2020/12/youe-info0.729842478879044   483.8            487.6      509.6
# 465   /2020/12/zahJuseum0.120647638596675   823.2            837.6      886.8
#
# ...

# %%
total_pageviews = transaction_01[['Product','pageviews']].groupby('Product').sum().reset_index()

# %%
total_revenue = revenue[['Product','SellPrice']].groupby('Product').sum().reset_index()

# %%
total_revenue.rename(columns={'SellPrice':'Revenue'},inplace=True)

# %%
total_revenue
# Out:
#                            Product  Revenue
# 0       007Jlease0.316606245376631     1870
# 1       007Ywatch0.906707330424838     1244
# 2       017Vorial0.336819995225967      843
# 3       032Olease0.888710698168418     2508
# 4       032ekbook0.534713694668182     3051
# ...                            ...      ...
# 13537    zoeu-news0.86467184397373     1233
# 13538   zoolakami0.244773192837841      365
# 13539  zozQation0.0106886180391892      604
# 13540   zozl-info0.445888607941033      577
# 13541   zseFtream0.740893188572541     1936
#
# [13542 rows x 2 columns]

# %%
total_pageviews
# Out:
#                            Product  pageviews
# 0       007Jlease0.316606245376631     1917.8
# 1       007Ywatch0.906707330424838     1045.6
# 2       017Vorial0.336819995225967      182.0
# 3       017Ylease0.197057924319041     1176.4
# 4       03-Hvideo0.644617973027599      568.6
# ...                            ...        ...
# 17884  zozQation0.0106886180391892     1329.8
# 17885   zoz[lease0.281797356811899      410.8
# 17886   zozl-info0.445888607941033      298.6
# 17887   zseFtream0.740893188572541       37.8
# 17888   zucKction0.211927037343636     1067.2
#
# [17889 rows x 2 columns]

# %%
product_info = total_pageviews.merge(total_revenue,on='Product',how='outer')

# %%
product_info.fillna(0,inplace=True)

# %%
product_info.sort_values('pageviews',ascending=False)
# Out:
#                           Product  pageviews  Revenue
# 14734  sonEies-x0.139039192479287   232177.0   1560.0
# 12990  porQlease0.507911745358356   170599.0   2714.0
# 13199  pumMvideo0.837931992780922   128891.8   3960.0
# 2585   besfeek-50.280274313298435   126771.0   2748.0
# 13853  rogLrecap0.644396392507623   124284.2   1197.0
# ...                           ...        ...      ...
# 16221  tisetream0.262717438134904        0.4    901.0
# 2948   bobK-news0.573637665518942        0.4    870.0
# 15459  sylEemand0.214265914271909        0.4      0.0
# 13446  recPeator0.470956776867346        0.4   3340.0
# 1695   ariDcle-20.188973495512866        0.4    645.0
#
# [17889 rows x 3 columns]

# %%
product_info.sort_values('Revenue',ascending=False)
# Out:
#                           Product  pageviews  Revenue
# 6929   hypsrview0.321288570724117      587.0  11556.0
# 13508  reeelease0.452821711209563      281.8   9205.0
# 1944   audE-info0.884915261087885     1205.6   8428.0
# 8310    kinv-news0.29905739542661      766.4   7980.0
# 17672  ymc_orson0.319251813809483      223.2   7794.0
# ...                           ...        ...      ...
# 14704  snoxeries0.164500840364095      205.4      0.0
# 8373   kobS-info0.635067468475914      202.0      0.0
# 8378   kobhction0.996773865773762     3463.6      0.0
# 8382   kobuespys0.676741221591199      730.2      0.0
# 17888  zucKction0.211927037343636     1067.2      0.0
#
# [17889 rows x 3 columns]

# %%
product_info.sort_values(['Revenue','pageviews'],ascending=False)
# Out:
#                           Product  pageviews  Revenue
# 6929   hypsrview0.321288570724117      587.0  11556.0
# 13508  reeelease0.452821711209563      281.8   9205.0
# 1944   audE-info0.884915261087885     1205.6   8428.0
# 8310    kinv-news0.29905739542661      766.4   7980.0
# 17672  ymc_orson0.319251813809483      223.2   7794.0
# ...                           ...        ...      ...
# 17806  yunUvideo0.199515319377547       21.2      0.0
# 17067  vibJtream0.961391666643217       19.8      0.0
# 1972   aur`bdrab0.327125310437019       10.8      0.0
# 9343   maju-date0.799046146817876        2.0      0.0
# 15459  sylEemand0.214265914271909        0.4      0.0
#
# [17889 rows x 3 columns]

# %%
product_info['pageviews'].describe()
# Out:
# count     17889.000000
# mean       1592.936453
# std        4412.133767
# min           0.400000
# 25%         358.800000
# 50%         683.600000
# 75%        1499.800000
# max      232177.000000
# Name: pageviews, dtype: float64

# %%
product_info['Revenue'].describe()
# Out:
# count    17889.000000
# mean      1141.328079
# std       1152.659037
# min          0.000000
# 25%        177.000000
# 50%        903.000000
# 75%       1632.000000
# max      11556.000000
# Name: Revenue, dtype: float64

# %%
else (3 if x < 1632 and x >= 903) 
                              else 2 if x < 903 and x >= 177 
                              else 1 if x < 177)

# %%
product_info['R'] = product_info['Revenue'].apply(lambda x: 4 if x>= 1632 else ( 3 if x < 1632 and x>= 903 
                                                            else (2 if x < 903 and x >= 177 else 
                                                                 1)))

# %%
product_info['P'] = product_info['pageviews'].apply(lambda x: 4 if x>= 1499 else ( 3 if x < 1499 and x>= 683.6 
                                                            else (2 if x < 683.6 and x >= 358 else 
                                                                 1)))

# %%
product_info[(product_info['R'] == 4) & (product_info['P'] == 4)]
# Out:
#                            Product  pageviews  Revenue  R  P
# 0       007Jlease0.316606245376631     1917.8   1870.0  4  4
# 14       10-Dhibli0.14039143981496     5006.4   2302.0  4  4
# 18      100E-info0.758794206933415     5884.4   1904.0  4  4
# 30      100okbook0.549659882803086     1938.6   2110.0  4  4
# 87      18mO-look0.123943498316578     3100.8   2642.0  4  4
# ...                            ...        ...      ... .. ..
# 17778   youptream0.973066697229772     1681.4   2154.0  4  4
# 17799   yumoweler0.449723494143297    14152.6   1960.0  4  4
# 17832  zacTeaser0.0185417998508631     2305.2   2186.0  4  4
# 17842   zahq-info0.658935603966331     1522.6   1734.0  4  4
# 17877   zioo-jazz0.731425393269566     5169.6   2572.0  4  4
#
# [1107 rows x 5 columns]

# %%
import seaborn as sns

# %%
sns.boxplot(y = product_info['pageviews'])

# %%
sns.boxplot(y = product_info['Revenue'])
